# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from keras.preprocessing.image import ImageDataGenerator

# %%
import json
def load_and_format(in_path):
    out_df = pd.read_json(in_path)  
    out_images = out_df.apply(lambda c_row: [np.stack([c_row['band_1'],c_row['band_2'],np.add(c_row['band_1'],c_row['band_2'])/2], -1).reshape((75,75,3))],1)
    out_images = np.stack(out_images).squeeze()
    return out_df, out_images
train_df, train_images = load_and_format('data/train.json')
print('training', train_df.shape, 'loaded', train_images.shape)
# Out:
# training (1604, 5) loaded (1604, 75, 75, 3)

# %%
from keras.utils.np_utils import to_categorical
X_img = train_images
X_ang = train_df['inc_angle'].replace('na',0) / 50
y = to_categorical(train_df['is_iceberg'])
print('Train', X_img.shape, y.shape)
# Out:
# Train (1604, 75, 75, 3) (1604, 2)

# %%
def plot_list(arr):
    fig = plt.figure()
    gs1 = gridspec.GridSpec(len(arr),1)
    for idx,ar in zip(range(len(arr)),arr):        
        ax = fig.add_subplot(gs1[idx])
        ax.plot(ar)
        
    gs1.tight_layout(fig)
    
import tensorflow as tf
def create_placeholders():
     ###place holders 
    global input_,input_post,label,keep_prob
    input_ = tf.placeholder(tf.float32, (None, 75, 75,3), name = 'features')
    input_post = tf.placeholder(tf.float32, (None,1), name = 'features2')
    label = tf.placeholder(tf.int32, (None, 2), name = 'labels')
    keep_prob = tf.placeholder(tf.float32)

tf.reset_default_graph()

with tf.Session() as sess:
    print(3)
    #X_train,X_train_ang,y_train = augment_func(sess,X_train,X_train_ang,y_train, times = 3)
# Out:
# 3

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.1), name="weight")

def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]), name ="bias")
def new_conv_layer(input,              # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape)

    # Create new biases, one for each filter.
    biases = new_biases(num_filters)
    
    # Note the strides are set to 1 in all dimensions.
    # The first and last stride must always be 1,
    # because the first is for the image-number and
    # the last is for the input-channel.
    # But e.g. strides=[1, 2, 2, 1] would mean that the filter
    # is moved 2 pixels across the x- and y-axis of the image.
    # The padding is set to 'SAME' which means the input image
    # is padded with zeroes so the size of the output is the same.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        # This is 2x2 max-pooling, which means that we
        # consider 2x2 windows and select the largest value
        # in each window. Then we move 2 pixels to the next window.
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    layer = tf.nn.relu(layer)

    return layer

# %%
num_channels = 3
# Convolutional Layer 1.
filter_size1 = 3          # Convolution filters are 5 x 5 pixels.
num_filters1 = 16         # There are 16 of these filters.

# Convolutional Layer 2.
filter_size2 = 3          # Convolution filters are 5 x 5 pixels.   222
num_filters2 = 16         # There are 36 of these filters.

# Convolutional Layer 3
filter_size3 = 3          # Convolution filters are 5 x 5 pixels.
num_filters3 = 32         # There are 36 of these filters.

# Convolutional Layer 4
filter_size4 = 3          # Convolution filters are 5 x 5 pixels.
num_filters4 = 32         # There are 36 of these filters.

# Convolutional Layer 5
filter_size5 = 3          # Convolution filters are 5 x 5 pixels.
num_filters5 = 32         # There are 36 of these filters.

# Fully-connected layer.
fc_size = 128           # Number of neurons in fully-connected layer.

# %%
def CNN(x):
   
    ####33##########
    #batch_norm = tf.layers.batch_normalization(x, training=is_train)
    
    layer_conv1 = new_conv_layer(input=x,
                       num_input_channels=num_channels,
                       filter_size=filter_size1,
                       num_filters=num_filters1,
                       use_pooling=False)
    layer_conv1 = new_conv_layer(input=layer_conv1,
                       num_input_channels=num_filters1,
                       filter_size=filter_size1,
                       num_filters=num_filters1,
                       use_pooling=True)
    drop_conv1 = tf.nn.dropout(layer_conv1, 0.80 + keep_prob*0.20)
    
    layer_conv2 = new_conv_layer(input=drop_conv1,
                       num_input_channels=num_filters1,
                       filter_size=filter_size2,
                       num_filters=num_filters2,
                       use_pooling=False)
    layer_conv2 = new_conv_layer(input=layer_conv2,
                       num_input_channels=num_filters2,
                       filter_size=filter_size2,
                       num_filters=num_filters2,
                       use_pooling=True)
    drop_conv2 = tf.nn.dropout(layer_conv2, 0.70 + keep_prob*0.30)
    
    layer_conv3 = new_conv_layer(input=drop_conv2,
                       num_input_channels=num_filters2,
                       filter_size=filter_size3,
                       num_filters=num_filters3,
                       use_pooling=False)
    layer_conv3 = new_conv_layer(input=layer_conv3,
                       num_input_channels=num_filters3,
                       filter_size=filter_size3,
                       num_filters=num_filters3,
                       use_pooling=True)
    drop_conv3 = tf.nn.dropout(layer_conv3, 0.60 + keep_prob*0.40)
    print(drop_conv3.shape)
    
    layer_conv4 = new_conv_layer(input=drop_conv3,
                       num_input_channels=num_filters3,
                       filter_size=filter_size4,
                       num_filters=num_filters4,
                       use_pooling=True)
    layer_conv4 = new_conv_layer(input=layer_conv4,
                       num_input_channels=num_filters4,
                       filter_size=filter_size4,
                       num_filters=num_filters4,
                       use_pooling=True)
    
    

    # Shortcut
    #flatten_layer = tf.contrib.layers.flatten(max_pool2)
    #fc = tf.contrib.layers.full_connected(flatten_layer, 256)
    
    # Long way of doing the fully_connected_layer
    _, height, width, depth = layer_conv4.shape
    print(layer_conv4.shape)
    tensor_size = int(height * width * depth +1) 
    flatten_layer = tf.reshape(layer_conv4, [-1, tensor_size-1])
    
    fc1_hidden_unit = int(tensor_size/6)
    print(fc1_hidden_unit)
    drop_fc1 = tf.nn.dropout(flatten_layer, 0.5 + keep_prob*0.5)
    drop_feat = tf.concat( [drop_fc1, input_post ], 1 )
    W_fc1 = new_weights([tensor_size, fc1_hidden_unit])
    b_fc1 = new_biases(fc1_hidden_unit)
    
    fc1 = tf.nn.relu(tf.add(tf.matmul(drop_feat, W_fc1), b_fc1))
    drop_fc2 = tf.nn.dropout(fc1, 0.50 + 0.50*keep_prob)   #85
    
    n_class = 2
    W_fc2 = new_weights([fc1_hidden_unit, n_class])
    b_fc2 = new_biases(n_class)
                     
    logits = tf.add(tf.matmul(drop_fc2, W_fc2), b_fc2)
    
    return logits

# %%
tf.reset_default_graph()
create_placeholders()
logits = CNN(input_)
logits_soft =tf.nn.softmax(logits)

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels = label, logits = logits)
step = tf.Variable(0,trainable=False)
#error = tf.square(label-logits)/2
var_s = tf.trainable_variables()
loss_l2 = tf.add_n([tf.nn.l2_loss(v) for v in var_s if 'bias' not in v.name])*0.001
loss = tf.reduce_mean(cross_entropy + loss_l2)
optimizer = tf.train.AdamOptimizer().minimize(loss)
accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(logits, 1), tf.argmax(label, 1)), tf.float32))
# Out:
# (?, 10, 10, 32)
# (?, 3, 3, 32)
# 48

# %%
epoch = 15
batch_size = 32

sess = tf.Session()
sess.run(tf.global_variables_initializer())

saver = tf.train.Saver()
best_accuracy,min_loss = 0,10
acc_rec, loss_rec = [], []

from sklearn.model_selection import KFold
kf = KFold(n_splits=5,shuffle=True)

from keras.preprocessing.image import ImageDataGenerator 
datagen = ImageDataGenerator(
                            width_shift_range=0.3,
                            height_shift_range=0.3,
                            zoom_range=0.2,
                            rotation_range =5,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')
datagen.fit(X_img)

# %%
kf = KFold(n_splits=5,shuffle=True)

# %%
for e in range(6):
    for train_index, test_index in kf.split(X_img):
        y_datagen = [[y[x,0],y[x,1],X_ang.values[x]] for x in train_index]
        i = 0
        for x_batch, y_batch in datagen.flow(X_img[train_index], y_datagen, batch_size=batch_size):
            sess.run([optimizer, loss], feed_dict = {input_: x_batch,
                                                     label: y_batch[:,:2],
                                                     input_post:y_batch[:,2:],
                                                     keep_prob:0
                                                     } )
            i +=1
            if i % 20 == 0:
                val_feed_dict = {input_: X_img[test_index],
                                 label: y[test_index],
                                 input_post:X_ang[test_index].values.reshape([-1,1]),
                                 keep_prob:1
                                 }
                val_loss = sess.run(loss, feed_dict = val_feed_dict)
                val_acc = accuracy.eval(feed_dict = val_feed_dict,session=sess)
                acc_rec.append(val_acc)
                loss_rec.append(val_loss)
                if val_acc > best_accuracy:
                    best_accuracy = val_acc
                    saver.save(sess, 'models/my_model_acc')
                    imp_str_acc = '*'*4
                else:
                    imp_str_acc = ''
                if val_loss<min_loss:
                    min_loss = val_loss
                    saver.save(sess, 'models/my_model_loss')
                    imp_str_loss = '*'*4
                else:
                    imp_str_loss = ''
                msg = "Epoch {}   Batch #{}: Valditaion Loss: {:.3}{}, Validation Accuracy: {:.3}{}"
                print(msg.format(e, i, val_loss,imp_str_loss, val_acc, imp_str_acc))
                if i >= len(y_datagen)/batch_size:
                    break
# Out:
# Epoch 0   Batch #20: Valditaion Loss: 0.334, Validation Accuracy: 0.891
# Epoch 0   Batch #40: Valditaion Loss: 0.334, Validation Accuracy: 0.888
# Epoch 0   Batch #60: Valditaion Loss: 0.387, Validation Accuracy: 0.854
# Epoch 0   Batch #20: Valditaion Loss: 0.297, Validation Accuracy: 0.888
# Epoch 0   Batch #40: Valditaion Loss: 0.332, Validation Accuracy: 0.863
# Epoch 0   Batch #60: Valditaion Loss: 0.303, Validation Accuracy: 0.894
# Epoch 0   Batch #20: Valditaion Loss: 0.343, Validation Accuracy: 0.863
# Epoch 0   Batch #40: Valditaion Loss: 0.342, Validation Accuracy: 0.844
# Epoch 0   Batch #60: Valditaion Loss: 0.301, Validation Accuracy: 0.869
# Epoch 0   Batch #20: Valditaion Loss: 0.357, Validation Accuracy: 0.872
# Epoch 0   Batch #40: Valditaion Loss: 0.388, Validation Accuracy: 0.875
# Epoch 0   Batch #60: Valditaion Loss: 0.308, Validation Accuracy: 0.891
# Epoch 0   Batch #20: Valditaion Loss: 0.369, Validation Accuracy: 0.872
# Epoch 0   Batch #40: Valditaion Loss: 0.323, Validation Accuracy: 0.872
# Epoch 0   Batch #60: Valditaion Loss: 0.333, Validation Accuracy: 0.875
# Epoch 1   Batch #20: Valditaion Loss: 0.349, Validation Accuracy: 0.857
# Epoch 1   Batch #40: Valditaion Loss: 0.338, Validation Accuracy: 0.882
# Epoch 1   Batch #60: Valditaion Loss: 0.359, Validation Accuracy: 0.857
# Epoch 1   Batch #20: Valditaion Loss: 0.303, Validation Accuracy: 0.897
# Epoch 1   Batch #40: Valditaion Loss: 0.313, Validation Accuracy: 0.9
# Epoch 1   Batch #60: Valditaion Loss: 0.354, Validation Accuracy: 0.885
# Epoch 1   Batch #20: Valditaion Loss: 0.313, Validation Accuracy: 0.888
# Epoch 1   Batch #40: Valditaion Loss: 0.304, Validation Accuracy: 0.888
# Epoch 1   Batch #60: Valditaion Loss: 0.31, Validation Accuracy: 0.894
# Epoch 1   Batch #20: Valditaion Loss: 0.347, Validation Accuracy: 0.875
# Epoch 1   Batch #40: Valditaion Loss: 0.429, Validation Accuracy: 0.832
# Epoch 1   Batch #60: Valditaion Loss: 0.441, Validation Accuracy: 0.804
# Epoch 1   Batch #20: Valditaion Loss: 0.293, Validation Accuracy: 0.884
# Epoch 1   Batch #40: Valditaion Loss: 0.429, Validation Accuracy: 0.819
# Epoch 1   Batch #60: Valditaion Loss: 0.294, Validation Accuracy: 0.872
# Epoch 2   Batch #20: Valditaion Loss: 0.344, Validation Accuracy: 0.866
# Epoch 2   Batch #40: Valditaion Loss: 0.368, Validation Accuracy: 0.866
# Epoch 2   Batch #60: Valditaion Loss: 0.333, Validation Accuracy: 0.879
# Epoch 2   Batch #20: Valditaion Loss: 0.292, Validation Accuracy: 0.894
# Epoch 2   Batch #40: Valditaion Loss: 0.288, Validation Accuracy: 0.888
# Epoch 2   Batch #60: Valditaion Loss: 0.267, Validation Accuracy: 0.916
# Epoch 2   Batch #20: Valditaion Loss: 0.325, Validation Accuracy: 0.891
# Epoch 2   Batch #40: Valditaion Loss: 0.332, Validation Accuracy: 0.875
# Epoch 2   Batch #60: Valditaion Loss: 0.353, Validation Accuracy: 0.882
# Epoch 2   Batch #20: Valditaion Loss: 0.306, Validation Accuracy: 0.875
# Epoch 2   Batch #40: Valditaion Loss: 0.26, Validation Accuracy: 0.916
# Epoch 2   Batch #60: Valditaion Loss: 0.297, Validation Accuracy: 0.903
# Epoch 2   Batch #20: Valditaion Loss: 0.382, Validation Accuracy: 0.844
# Epoch 2   Batch #40: Valditaion Loss: 0.31, Validation Accuracy: 0.909
# Epoch 2   Batch #60: Valditaion Loss: 0.355, Validation Accuracy: 0.875
# Epoch 3   Batch #20: Valditaion Loss: 0.272, Validation Accuracy: 0.897
# Epoch 3   Batch #40: Valditaion Loss: 0.296, Validation Accuracy: 0.907
# Epoch 3   Batch #60: Valditaion Loss: 0.303, Validation Accuracy: 0.882
# Epoch 3   Batch #20: Valditaion Loss: 0.351, Validation Accuracy: 0.869
# Epoch 3   Batch #40: Valditaion Loss: 0.276, Validation Accuracy: 0.907
# Epoch 3   Batch #60: Valditaion Loss: 0.288, Validation Accuracy: 0.903
# Epoch 3   Batch #20: Valditaion Loss: 0.408, Validation Accuracy: 0.832
# Epoch 3   Batch #40: Valditaion Loss: 0.459, Validation Accuracy: 0.798
# Epoch 3   Batch #60: Valditaion Loss: 0.329, Validation Accuracy: 0.897
# Epoch 3   Batch #20: Valditaion Loss: 0.256, Validation Accuracy: 0.903
# Epoch 3   Batch #40: Valditaion Loss: 0.253, Validation Accuracy: 0.916
# Epoch 3   Batch #60: Valditaion Loss: 0.275, Validation Accuracy: 0.913
# Epoch 3   Batch #20: Valditaion Loss: 0.431, Validation Accuracy: 0.828
# Epoch 3   Batch #40: Valditaion Loss: 0.332, Validation Accuracy: 0.891
# Epoch 3   Batch #60: Valditaion Loss: 0.337, Validation Accuracy: 0.881
# Epoch 4   Batch #20: Valditaion Loss: 0.286, Validation Accuracy: 0.903
# Epoch 4   Batch #40: Valditaion Loss: 0.397, Validation Accuracy: 0.847
# Epoch 4   Batch #60: Valditaion Loss: 0.319, Validation Accuracy: 0.869
# Epoch 4   Batch #20: Valditaion Loss: 0.27, Validation Accuracy: 0.922
# Epoch 4   Batch #40: Valditaion Loss: 0.297, Validation Accuracy: 0.903
# Epoch 4   Batch #60: Valditaion Loss: 0.262, Validation Accuracy: 0.903
# Epoch 4   Batch #20: Valditaion Loss: 0.317, Validation Accuracy: 0.894
# Epoch 4   Batch #40: Valditaion Loss: 0.323, Validation Accuracy: 0.885
# Epoch 4   Batch #60: Valditaion Loss: 0.312, Validation Accuracy: 0.894
# Epoch 4   Batch #20: Valditaion Loss: 0.378, Validation Accuracy: 0.838
# Epoch 4   Batch #40: Valditaion Loss: 0.34, Validation Accuracy: 0.866
# Epoch 4   Batch #60: Valditaion Loss: 0.336, Validation Accuracy: 0.872
# Epoch 4   Batch #20: Valditaion Loss: 0.28, Validation Accuracy: 0.906
# Epoch 4   Batch #40: Valditaion Loss: 0.313, Validation Accuracy: 0.894
# Epoch 4   Batch #60: Valditaion Loss: 0.271, Validation Accuracy: 0.906
# Epoch 5   Batch #20: Valditaion Loss: 0.313, Validation Accuracy: 0.9
# Epoch 5   Batch #40: Valditaion Loss: 0.365, Validation Accuracy: 0.847
# Epoch 5   Batch #60: Valditaion Loss: 0.328, Validation Accuracy: 0.872
# Epoch 5   Batch #20: Valditaion Loss: 0.249****, Validation Accuracy: 0.928
# Epoch 5   Batch #40: Valditaion Loss: 0.267, Validation Accuracy: 0.916
# Epoch 5   Batch #60: Valditaion Loss: 0.255, Validation Accuracy: 0.91
# Epoch 5   Batch #20: Valditaion Loss: 0.322, Validation Accuracy: 0.885
# Epoch 5   Batch #40: Valditaion Loss: 0.311, Validation Accuracy: 0.869
# Epoch 5   Batch #60: Valditaion Loss: 0.318, Validation Accuracy: 0.879
# Epoch 5   Batch #20: Valditaion Loss: 0.26, Validation Accuracy: 0.919
# Epoch 5   Batch #40: Valditaion Loss: 0.268, Validation Accuracy: 0.916
# Epoch 5   Batch #60: Valditaion Loss: 0.273, Validation Accuracy: 0.903
# Epoch 5   Batch #20: Valditaion Loss: 0.349, Validation Accuracy: 0.859
# Epoch 5   Batch #40: Valditaion Loss: 0.506, Validation Accuracy: 0.797
# Epoch 5   Batch #60: Valditaion Loss: 0.418, Validation Accuracy: 0.825

# %%
# %matplotlib notebook

plot_list([acc_rec,loss_rec])
print('best Acc: {:.3}, Min loss: {:.3}'.format(best_accuracy,min_loss))
# Out:
# <img src="data:image/png;base64,..." width="640">
# best Acc: 0.938, Min loss: 0.249

# %%
loss_rec = np.array(loss_rec)
loss_rec[acc_rec[:]==max(acc_rec)]
# Out:
# array([ 0.2517595], dtype=float32)

# %%
np.floor(1.8)
# Out:
# 1.0

# %%
def predict_batch(test_imgages,inc_ang,length = 1000):
    prev_index = 0
    for x in range(int(np.floor(len(inc_ang)/length))):
        index = (x+1) * length
        feed_dict_sub = {input_: test_imgages[prev_index:index], input_post:inc_ang[prev_index:index], keep_prob:1} 
        
        
        pred = sess.run(logits_soft,feed_dict=feed_dict_sub)
        if x == 0:
            return_sub = pred
        else:
            return_sub = np.concatenate((return_sub,pred))
        prev_index = index
    feed_dict_sub = {input_: test_imgages[prev_index:], input_post:inc_ang[prev_index:], keep_prob:1} 
    pred = sess.run(logits_soft,feed_dict=feed_dict_sub)
    return_sub = np.concatenate((return_sub,pred))
    return return_sub

# %%
test_df, test_imgages = load_and_format('data/test.json')
print('ok')
# Out:
# ok

# %%
inc_ang = test_df['inc_angle'].replace('na',0) / 50
inc_ang = inc_ang.as_matrix().reshape([-1,1])

# %%
saver.restore(sess,"models/my_model_loss")
sub_loss = predict_batch(test_imgages,inc_ang)
saver.restore(sess,"models/my_model_acc")
sub_acc = predict_batch(test_imgages,inc_ang)
# Out:
# INFO:tensorflow:Restoring parameters from models/my_model_loss
# INFO:tensorflow:Restoring parameters from models/my_model_acc

# %%
sub_loss = [1-p[0] if np.argmax(p)==0 else p[1]  for p in sub_loss]
sub_acc = [1-p[0] if np.argmax(p)==0 else p[1]  for p in sub_acc]
sub_data = (np.array(sub_loss) + np.array(sub_acc))/2

# %%
sub = pd.DataFrame()
sub['id'] = test_df['id']
sub['is_iceberg'] = sub_data

# %%
sub.to_csv("sub/sub_loss{:.3}_acc{:.3}.csv".format(min_loss,best_accuracy), index = False)
